# %% [markdown]
# # [ECE 2112] ADVANCED COMPUTER PROGRAMMING AND ALGORITHMS

# %% [markdown]
# ##### S.Y. ‘26 - ‘27 | SECOND YEAR | FIRST SEM | hzlcbl

# %% [markdown]
# ### **MODULE 2: Numpy**

# %% [markdown]
# **Numerical Python (Numpy)** - core library for **scientific computing** in Python. It provides a high performance multidimensional array object and tools for working with arrays.

# %% [markdown]
# **Array** - a data structure that <span class="hl">stores multiple items of the same data type</span> together under one name

# %% [markdown]
# To access Numpy library, the import convention must be used: import numpy as np

# %%
import numpy as np

# %% [markdown]
# **ndarray** - mulidimensional containder of items of the same type and size

# %% [markdown]
# The **number of dimensions and items** in an array is defined by its **shape**, which is a **tuple of N non-negative integers** that specify the sizes of each dimension.

# %% [markdown]
# **dtype** specifies the type of items in the array

# %% [markdown]
# #### **Common Data Types for items in ndarrays**

# %% [markdown]
# | dtype | Description |
# | :---: | :--- |
# | np.int64 | Signed 64-bit integer types |
# | np.float32 | Standard double-precision floating point |
# | np.complex | Complex numbers represented by 128 floats |
# | np.bool | Boolean type storing TRUE and FALSE values |
# | np.object | Python object type |
# | np.string_ | Fixed-length string type |
# | np.unicode_ | Fixed-length unicode type |

# %% [markdown]
# #### **Python Demo 1: Creating and Inspecting ndarrays**

# %% [markdown]
# ![image.png](attachment:24348f04-6b82-411d-bf7f-7110b8ee6cc0.png)

# %%
#1D Array - vector
el = np.array([1,2,3])
el
# Out:
# array([1, 2, 3])

# %% [markdown]
# ##### **Format Code**

# %%
# %%html
# <style>
#   .hl {
#     background-color: #fae6ef;
#     color: black;
#     padding: 2px 4px;
#     border-radius: 3px;
#   }
# </style>
# Out:
# <style>
#   .hl {
#     background-color: #fae6ef;
#     color: black;
#     padding: 2px 4px;
#     border-radius: 3px;
#   }
# </style>
